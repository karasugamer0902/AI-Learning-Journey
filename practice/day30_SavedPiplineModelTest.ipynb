# %%
import joblib
import pandas as pd

# %%
my_AIpipline = joblib.load('super_stable_model_v2.pkl')

new_test = pd.DataFrame({
    '年齡': [None],
    '讀書小時': [18], 
    '性別': ['男']
})

final_result = my_AIpipline.predict(new_test)
print(f"自動補洞後的預測結果：{final_result[0]:.2f} 分")
# Out:
# 自動補洞後的預測結果：70.36 分
