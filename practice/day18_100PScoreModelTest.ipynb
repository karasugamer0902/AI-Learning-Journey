# %%
import pandas as pd
import joblib

# %%
my_ai = joblib.load('100people_score_model.pkl')

input_data = pd.DataFrame({"age": [35], "hours": [12]})

TheResult = my_ai.predict(input_data)
print(f"根據百人數據分析，這名學生的預測分數為：{TheResult[0]:.2f} 分")
# Out:
# 根據百人數據分析，這名學生的預測分數為：317.86 分
